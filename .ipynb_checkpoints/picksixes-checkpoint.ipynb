# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %%
def seasonState(row):
    if row.S <= 15:
        wks = 14
    elif row.S <= 22:
        wks = 13
    else:
        wks = 16
        
    if row.W > wks:
        return "Postseason"
    else:
        return "Regular Season"

# %%
all_files = ["PBP/S%iPBP.csv"%(i) for i in range(1,26)]

df = pd.concat((pd.read_csv(f) for f in all_files)).reset_index()
df.loc[:,'seasonState'] = df.apply(lambda x: seasonState(x),axis=1)
# regDF = df.loc[df['seasonState'] == 'Regular Season'].reset_index()
regDF = df.copy()

TDs = regDF.iloc[regDF[regDF['play'].str.contains("TOUCHDOWN")].index - 1]

picksix = TDs[TDs['play'].str.contains('INTERCEPTION')]
scoop = TDs[TDs['play'].str.contains('FUMBLE')]
QBlist = pd.DataFrame(picksix['play'].str.replace("Pass by ","").str.replace(r" \(.*?\)","").str.replace(r"\(.*?\) ","").str.split(', to').str[0])
picksix['QB'] = QBlist
QBlist['play'].value_counts().to_csv('PickSix_S25.csv')
# Out:
# /home/mike/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
scoop
# Out:
#         index  Unnamed: 0  teamID  Q   time  totTime  down  distance side  \
# 17864    8844         146       6  3   2:47     1067   3.0       9.0  SJS
# 45980   11837         155       7  3   4:23     1163   3.0      16.0  PHI
# 52198    5258          53       3  1   1:55     2815   2.0      21.0  COL
# 102760   3860         172       5  4   3:39      219   2.0      16.0  OCO
# 109479  10579         186       7  4  13:02      782   2.0      10.0  PHI
# 176006   1174          68       3  2  10:27     2427   2.0      17.0  COL
# 189085   1794         131      10  3   1:50     1010   3.0      10.0  AUS
# 214798  12189          67       5  2  10:09     2409   3.0       6.0  OCO
# 222426   4693          91       4  2   0:29     1829   1.0      10.0   AZ
#
#         yard                                               play  gameID   S  \
# 17864   21.0  Rush by Hunt, E. for a short gain. Tackle by F...     112   2
# 45980   16.0  Rove, C. SACKED by Dental Dam - DE for -10 yds...     778   4
# 52198    8.0  Rush by Farlane, D. for 6 yds. Tackle by Ridle...    1398   5
# 102760  11.0  Pass by Boss, M., complete to Atwell, T. for 5...    2334   9
# 109479  11.0  Noble, L. SACKED by Arbin Asipi Jr. - DE for -...    2365   9
# 176006   2.0  Rush by Taffy, T. for a short gain. Tackle by ...    3362  15
# 189085  20.0  Cole (R), E. SACKED by Raymond Vans - LB for -...    3877  16
# 214798  29.0  Armstrong (R), F. SACKED by Steven Oats - DE f...    4346  17
# 222426   5.0  Rush by Reese, A. for 1 yds. Tackle by Burr-Ki...    4579  18
#
#          W teamPoss  dist2goal awayTeam homeTeam  awayScore  homeScore  \
# 17864   11      SJS       79.0      COL      SJS          7          6
# 45980   14      PHI       84.0      PHI      BAL         28         17
# 52198    7      COL       92.0      COL      YKW         14         14
# 102760   5      OCO       89.0      OCO      YKW         13         21
# 109479  13      PHI       89.0      PHI      BAL          7         40
# 176006   2      COL       98.0      COL       AZ         10         10
# 189085   2      AUS       80.0       AZ      AUS          3          3
# 214798  12      OCO       71.0      OCO      BAL         10          7
# 222426   5       AZ       95.0      SJS       AZ          3         21
#
#            seasonState
# 17864   Regular Season
# 45980   Regular Season
# 52198   Regular Season
# 102760  Regular Season
# 109479  Regular Season
# 176006  Regular Season
# 189085  Regular Season
# 214798  Regular Season
# 222426  Regular Season

# %%
[scoop.play.iloc[i] for i in range(len(scoop))]
# Out:
# ['Rush by Hunt, E. for a short gain. Tackle by Fulton, W.. FUMBLE recovered by Fulton, W. at the SJS - 21 yard line and returned for 21 yards.',
#  'Rove, C. SACKED by Dental Dam - DE for -10 yds. FUMBLE recovered by Dam, D. at the PHI - 6 yard line and returned for 6 yards.',
#  'Rush by Farlane, D. for 6 yds. Tackle by Ridley, W.. FUMBLE recovered by Kane, M. at the COL - 14 yard line and returned for 14 yards.',
#  'Pass by Boss, M., complete to Atwell, T. for 5 yds. Tackle by Stone, W.. FUMBLE recovered by Taylor, C. at the OCO - 16 yard line and returned for 16 yards.',
#  'Noble, L. SACKED by Arbin Asipi Jr. - DE for -10 yds. FUMBLE recovered by Asipi Jr., A. at the PHI - 1 yard line and returned for 1 yards.',
#  'Rush by Taffy, T. for a short gain. Tackle by Morris, R.. FUMBLE recovered by Morris, R. at the COL - 2 yard line and returned for 2 yards.',
#  'Cole (R), E. SACKED by Raymond Vans - LB for -6 yds. FUMBLE recovered by Vans, R. at the AUS - 14 yard line and returned for 14 yards.',
#  'Armstrong (R), F. SACKED by Steven Oats - DE for -6 yds. FUMBLE recovered by Oats, S. at the OCO - 23 yard line and returned for 23 yards.',
#  'Rush by Reese, A. for 1 yds. Tackle by Burr-Kirven, J.. FUMBLE recovered by Grimnir (R), O. at the AZ - 6 yard line and returned for 6 yards.']

# %%
QBlist['play'].value_counts()
# Out:
# Christ, J.            20
# McDummy, W.           19
# Maximus III, B.       19
# Boss, M.              18
# Orosz, C.             15
# Bigsby, C.            14
# Cole, E.              14
# Applehort, R.         14
# Akselsen, M.          14
# Pierno, N.            14
# Francisco, S.         14
# Falconi, A.           13
# Jenkins, R.           13
# Showbiz, G.           13
# McCormick, M.         13
# Armstrong, F.         11
# Reese, A.             11
# Bronko, K.            11
# Cue, J.               10
# Fitzpatrick, K.       10
# Hunt, E.              10
# Kyubee, S.            10
# Havran, C.            10
# Pennington, B.        10
# Fujiwara, C.          10
# Wright, D.             9
# Bercovici, J.          9
# Blocksdale, A.         9
# Rove, C.               8
# Noble, L.              8
# Gambino, C.            8
# Banks II, D.           6
# Oles, T.               5
# Jack, C.               5
# Phoenix, B.            4
# O'Donnell, G.          4
# Howitzer, S.           4
# Skywalker, L.          4
# Jack, M.               4
# Stone, W.              3
# Draxel, V.             2
# Ramza, S.              2
# Slothlisberger, B.     2
# Kaepercolin, N.        2
# LaFleur, F.            1
# Jack, ".               1
# Holder, P.             1
# Name: play, dtype: int64

# %% [markdown]
# Note: the last row (`Jack, ".`) is Monty Jack.

# %%
picksix[picksix.play.str.contains("Jack")]
# Out:
#         index  Unnamed: 0  teamID  Q   time  totTime  down  distance side  \
# 30441    9077           3       6  1  14:50     3590   1.0      10.0  SJS
# 33254   11890           4       6  1  14:22     3562   3.0       5.0  SJS
# 33311   11947          61       6  2  12:35     2555   3.0       7.0  SJS
# 221774   4041         101       8  2   5:28     2128   2.0       9.0   NO
# 225964   8231         148       8  3   8:06     1386   1.0      10.0   NO
# 253527   5761          74       6  2   6:13     2173   1.0      10.0  SJS
# 255746   7980          25       6  1   8:43     3223   2.0       6.0  SJS
# 261149  13383          51       6  1   1:13     2773   1.0      10.0  SJS
# 314033  18375         171       6  4  10:54      654   1.0      10.0  SJS
# 314487  18829           4       2  1  14:14     3554   3.0      16.0  YKW
# 317250    289          63       2  2  11:16     2476   1.0      10.0  YKW
# 326545   9584         146       2  3   2:51     1071   1.0      10.0  AUS
# 326882   9921          72       6  2   5:32     2132   1.0      10.0  SJS
# 330716  13755          39       2  1   0:01     2701   2.0       6.0  PHI
# 338431     87          87       6  2   1:43     1903   1.0      10.0  OCO
# 342952   4608         123       6  3  14:51     1791   1.0      15.0  SJS
# 343323   4979          50       2  1   1:29     2789   1.0      10.0  YKW
# 354801  16457          50       6  2  15:00     2700   3.0       4.0  SJS
# 357632  19288         198       2  4   3:26      206   3.0       8.0  YKW
#
#         yard                                               play  gameID   S  \
# 30441   40.0  Pass by Hunt, E., to Jackson, M.. INTERCEPTION...     318   3
# 33254   31.0  Pass by Hunt, E., to Jackson, M.. INTERCEPTION...     331   3
# 33311   23.0  Pass by Hunt, E., to Jackson, M.. INTERCEPTION...     331   3
# 221774  50.0  Pass by Francisco, S., to Jackson, A.. INTERCE...    4576  18
# 225964  37.0  Pass by Francisco, S., to Jackson, A.. INTERCE...    4596  18
# 253527  23.0  Pass by Wright, D., to Jackson, A.. INTERCEPTI...    4998  20
# 255746  35.0  Pass by Wright, D., to Jackson, A.. INTERCEPTI...    5009  20
# 261149  20.0  Pass by Wright, D., to Jackson, A.. INTERCEPTI...    5034  20
# 314033  17.0  Pass by Jack (R), "., to Lackson (R), J.. INTE...    5684  23
# 314487   9.0  Pass by Bigsby, C., to Jackson, A.. INTERCEPTI...    5687  23
# 317250  17.0  Pass by Jack (R), C., to Cash Jr. (R), S.. INT...    6181  24
# 326545  13.0  Pass by Jack (R), C., to Sakura (R), K.. INTER...    6142  24
# 326882  20.0  Pass by Jack, M., to Cardrissian, R.. INTERCEP...    6132  24
# 330716  31.0  Pass by Jack (R), C., to Sakura (R), K.. INTER...    6115  24
# 338431  28.0  Pass by Jack, M., to Cardrissian, R.. INTERCEP...    6369  25
# 342952  47.0  Pass by Jack, M., to Cardrissian, R.. INTERCEP...    6390  25
# 343323  30.0  Pass by Jack, C., to Sakura (C), K.. INTERCEPT...    6392  25
# 354801  26.0  Pass by Jack, M., to Cardrissian, R.. INTERCEP...    6446  25
# 357632  42.0  Pass by Jack, C., to Rechs (R), Z.. INTERCEPTI...    6458  25
#
#          W teamPoss  dist2goal awayTeam homeTeam  awayScore  homeScore  \
# 30441   11      SJS       60.0      SJS      BAL          0          0
# 33254   14      SJS       69.0      SJS      COL          0          0
# 33311   14      SJS       77.0      SJS      COL          0         14
# 221774   4       NO       50.0      COL       NO         17         10
# 225964   8       NO       63.0       NO      AUS         21         13
# 253527   6      SJS       77.0      SJS      AUS         10         21
# 255746   8      SJS       65.0      OCO      SJS          2          0
# 261149  13      SJS       80.0      YKW      SJS          7          7
# 314033  15      SJS       83.0      OCO      SJS         37          6
# 314487  16      YKW       91.0      YKW      PHI          0          0
# 317250   1      YKW       83.0      YKW      PHI          7          7
# 326545   8      YKW       13.0      AUS      YKW         27          6
# 326882   9      SJS       80.0      BAL      SJS          3          7
# 330716  12      YKW       31.0      PHI      YKW          0          0
# 338431   1      SJS       28.0      SJS      OCO          3          6
# 342952   4      SJS       53.0      HON      SJS         14         14
# 343323   4      YKW       70.0      YKW       NO          3          3
# 354801  12      SJS       74.0      SJS       AZ          0         14
# 357632  13      YKW       58.0      YKW      BER         30         23
#
#            seasonState             QB
# 30441   Regular Season       Hunt, E.
# 33254   Regular Season       Hunt, E.
# 33311   Regular Season       Hunt, E.
# 221774  Regular Season  Francisco, S.
# 225964  Regular Season  Francisco, S.
# 253527  Regular Season     Wright, D.
# 255746  Regular Season     Wright, D.
# 261149  Regular Season     Wright, D.
# 314033  Regular Season       Jack, ".
# 314487  Regular Season     Bigsby, C.
# 317250  Regular Season       Jack, C.
# 326545  Regular Season       Jack, C.
# 326882  Regular Season       Jack, M.
# 330716  Regular Season       Jack, C.
# 338431  Regular Season       Jack, M.
# 342952  Regular Season       Jack, M.
# 343323  Regular Season       Jack, C.
# 354801  Regular Season       Jack, M.
# 357632  Regular Season       Jack, C.

# %% [markdown]
# Also note that Joliet and Jameis Christ are combined. Joliet did not start playing until S11.

# %%
picksix[picksix.play.str.contains("Christ, J.")]
# Out:
#         index  Unnamed: 0  teamID  Q   time  totTime  down  distance side  \
# 2536     2536         163       6  4   9:26      566   1.0      10.0  SJS
# 3369     3369           5       6  1  13:40     3520   3.0      16.0  SJS
# 3540     3540         176       6  4   8:15      495   3.0       6.0  SJS
# 4688     4688         101       6  3  12:20     1640   2.0      10.0  OCO
# 9581      561         169       7  4  11:50      710   1.0      10.0  PHI
# 18889    9869          87       7  2   5:25     2125   3.0      21.0  PHI
# 124971    567         154       6  3   0:09      909   2.0       3.0  SJS
# 126471   2067          98       6  2   2:18     1938   3.0      11.0  SJS
# 126517   2113         144       6  3   4:08     1148   2.0       6.0  SJS
# 131055   6651          36       6  1   5:14     3014   1.0      10.0  SJS
# 132145   7741          42       6  1   2:07     2827   3.0      10.0  SJS
# 140236   2962          73       6  2  10:51     2451   3.0       8.0  SJS
# 149584  12310         114       6  3   8:13     1393   2.0      13.0  SJS
# 151413   1503         107       6  2   0:02     1802   2.0      10.0  SJS
# 159580   9670         176       6  4  13:45      825   3.0       8.0  SJS
# 174688  12276          57       6  2  11:24     2484   3.0       9.0  SJS
# 185751  10919          75       6  2   5:56     2156   3.0       7.0  SJS
# 189510   2219         148       6  3   4:44     1184   1.0      10.0  SJS
# 201789  14498          72       6  2   9:15     2355   2.0      25.0  SJS
# 214664  12055         124       6  3   7:49     1369   2.0       9.0  SJS
#
#         yard                                               play  gameID   S  \
# 2536     7.0  Pass by Christ, J., to Bottles, B.. INTERCEPTI...      23   1
# 3369     9.0  Pass by Christ, J., to Cook, B.. INTERCEPTION ...      34   1
# 3540    49.0  Pass by Christ, J., to Weston, S.. INTERCEPTIO...      34   1
# 4688    37.0  Pass by Christ, J., to Cook, B.. INTERCEPTION ...      13   1
# 9581    30.0  Pass by Christ, J., to Kroetch, D.. INTERCEPTI...     113   2
# 18889   36.0  Pass by Christ, J., to Newman, M.. INTERCEPTIO...      74   2
# 124971  27.0  Pass by (R) Christ, J., to Oles, K.. INTERCEPT...    2673  11
# 126471  37.0  Pass by (R) Christ, J., to Weston, S.. INTERCE...    2680  11
# 126517  26.0  Pass by (R) Christ, J., to Flash, X.. INTERCEP...    2680  11
# 131055  20.0  Pass by (R) Christ, J., to Flash, X.. INTERCEP...    2701  11
# 132145  27.0  Pass by (R) Christ, J., to Oles, K.. INTERCEPT...    2706  11
# 140236   6.0  Pass by Christ, J., to Oles, K.. INTERCEPTION ...    2891  12
# 149584  17.0  Pass by Christ, J., to Orosz, C.. INTERCEPTION...    2935  12
# 151413  20.0  Pass by Christ, J., to Brannigan, Z.. INTERCEP...    3019  13
# 159580  22.0  Pass by Christ, J., to Canton, J.. INTERCEPTIO...    3057  13
# 174688  41.0  Pass by Christ, J., to Brannigan, Z.. INTERCEP...    3263  14
# 185751   6.0  Pass by Christ, J., to Justice, T.. INTERCEPTI...    3408  15
# 189510  38.0  Pass by Christ, J., to Flash, X.. INTERCEPTION...    3879  16
# 201789  40.0  Pass by Christ, J., to Wright, D.. INTERCEPTIO...    3937  16
# 214664  36.0  Pass by Christ, J., to Flash, X.. INTERCEPTION...    4345  17
#
#          W teamPoss  dist2goal awayTeam homeTeam  awayScore  homeScore  \
# 2536     5      SJS       93.0      SJS      BAL         17         20
# 3369     6      SJS       91.0      SJS      ARI          0          0
# 3540     6      SJS       51.0      SJS      ARI          3         16
# 4688     8      SJS       37.0      SJS      OCO          0         14
# 9581     1      PHI       70.0      PHI      SJS         16         24
# 18889   12      PHI       64.0      PHI      COL         14         10
# 124971   1      SJS       73.0      SJS      OCO          7          6
# 126471   3      SJS       63.0      SJS      COL          7         13
# 126517   3      SJS       74.0      SJS      COL          7         27
# 131055   8      SJS       80.0      OCO      SJS          7          7
# 132145   9      SJS       73.0      SJS      PHI          3          7
# 140236   4      SJS       94.0      OCO      SJS          0          0
# 149584  15      SJS       83.0      SJS      OCO         10          7
# 151413   2      SJS       80.0       NO      SJS         16          7
# 159580  12      SJS       78.0      SJS       NO         24          7
# 174688  16      SJS       59.0      PHI      SJS          3          6
# 185751  13      SJS       94.0       NO      SJS          0         17
# 189510   3      SJS       62.0      YKW      SJS         10         10
# 201789  14      SJS       60.0      SJS       AZ          0         17
# 214664  12      SJS       64.0      YKW      SJS         13          3
#
#            seasonState          QB
# 2536    Regular Season  Christ, J.
# 3369    Regular Season  Christ, J.
# 3540    Regular Season  Christ, J.
# 4688    Regular Season  Christ, J.
# 9581    Regular Season  Christ, J.
# 18889   Regular Season  Christ, J.
# 124971  Regular Season  Christ, J.
# 126471  Regular Season  Christ, J.
# 126517  Regular Season  Christ, J.
# 131055  Regular Season  Christ, J.
# 132145  Regular Season  Christ, J.
# 140236  Regular Season  Christ, J.
# 149584      Postseason  Christ, J.
# 151413  Regular Season  Christ, J.
# 159580  Regular Season  Christ, J.
# 174688      Postseason  Christ, J.
# 185751  Regular Season  Christ, J.
# 189510  Regular Season  Christ, J.
# 201789      Postseason  Christ, J.
# 214664  Regular Season  Christ, J.

# %%
picksix[picksix.play.str.contains("Maximus")]
# Out:
#         index  Unnamed: 0  teamID  Q   time  totTime  down  distance side  \
# 63986    4364          18       8  1  12:00     3420   1.0      10.0   NO
# 64070    4448         102       8  2   2:45     1965   2.0       5.0   NO
# 68808    9186         175       8  4   5:47      347   3.0       1.0   NO
# 74803    2196         111       8  2   2:38     1958   1.0      10.0   NO
# 85127   12520          38       8  1   5:04     3004   1.0      10.0   NO
# 86299     300          75       8  2   6:34     2194   1.0      10.0  YKW
# 113384   1680          10       8  1  13:11     3491   1.0      10.0   NO
# 114902   3198          41       8  1   5:51     3051   3.0      12.0   NO
# 119153   7449         124       8  3  11:06     1566   3.0       9.0   NO
# 127877   3473         183       8  4  11:30      690   2.0       4.0   NO
# 137768    494          44       8  1   1:23     2783   1.0      10.0   NO
# 137785    511          61       8  2  12:09     2529   3.0       6.0   NO
# 153996   4086         180       8  4   9:42      582   3.0      10.0   NO
# 161089  11179          95       8  2   2:39     1959   1.0      10.0   NO
# 169319   6907         183       8  4   3:29      209   1.0      10.0   NO
# 172417  10005          95       8  3  14:16     1756   2.0       1.0  COL
# 176494   1662         162       8  4  14:52      892   1.0      10.0   NO
# 176630   1798          87       8  2   1:52     1912   2.0       5.0   NO
# 186475  11643           6       8  1  13:26     3506   2.0      10.0  BAL
#
#         yard                                               play  gameID   S  \
# 63986   35.0  Pass by Maximus III, B., to Evans, D.. INTERCE...    1598   6
# 64070    6.0  Pass by Maximus III, B., to Booter, F.. INTERC...    1598   6
# 68808   29.0  Pass by Maximus III, B., to Omega, K.. INTERCE...    1619   6
# 74803   20.0  Pass by Maximus III, B., to Evans, D.. INTERCE...    1737   7
# 85127   20.0  Pass by Maximus III, B., to Savea, A.. INTERCE...    1783   7
# 86299   49.0  Pass by Maximus III, B., to Smallwood, D.. INT...    1880   8
# 113384  32.0  Pass by Maximus III, B., to DiMirio, P.. INTER...    2530  10
# 114902  18.0  Pass by Maximus III, B., to LeClair, A.. INTER...    2537  10
# 119153   2.0  Pass by Maximus III, B., to Crush, C.. INTERCE...    2556  10
# 127877  26.0  Pass by Maximus III, B., to DiMirio, P.. INTER...    2686  11
# 137768  30.0  Pass by Maximus III, B., to Fyodorovich, V.. I...    2880  12
# 137785  17.0  Pass by Maximus III, B., to DiMirio, P.. INTER...    2880  12
# 153996  30.0  Pass by Maximus III, B., to Halvorsen, T.. INT...    3031  13
# 161089  19.0  Pass by Maximus III, B., to DiMirio, P.. INTER...    3064  13
# 169319  33.0  Pass by Maximus III, B., to (R) Francisco, S.....    3237  14
# 172417  45.0  Pass by Maximus III, B., to Fyodorovich, V.. I...    3252  14
# 176494   1.0  Pass by Maximus III, B., to Francisco, S.. INT...    3364  15
# 176630  31.0  Pass by Maximus III, B., to Fyodorovich, V.. I...    3365  15
# 186475  48.0  Pass by Maximus III, B., to Swift, T.. INTERCE...    3412  15
#
#          W teamPoss  dist2goal awayTeam homeTeam  awayScore  homeScore  \
# 63986    6       NO       65.0       NO      BAL          0          0
# 64070    6       NO       94.0       NO      BAL          0          7
# 68808   11       NO       71.0       NO      YKW         20         17
# 74803    3       NO       80.0       NO      YKW          3         23
# 85127   14       NO       80.0       AZ       NO          0         10
# 86299    1       NO       49.0      YKW       NO         10          7
# 113384   3       NO       68.0      YKW       NO          0          0
# 114902   4       NO       82.0       NO      COL          7          0
# 119153   9       NO       98.0      OCO       NO          0         27
# 127877   4       NO       74.0      COL       NO         20         36
# 137768   1       NO       70.0       NO      SJS          0          7
# 137785   1       NO       83.0       NO      SJS          0         14
# 153996   5       NO       70.0       NO       AZ         10         42
# 161089  14       NO       81.0      OCO       NO          0         10
# 169319   9       NO       67.0       NO      YKW         14         27
# 172417  12       NO       45.0      COL       NO         10         10
# 176494   2       NO       99.0      PHI       NO         23         14
# 176630   3       NO       69.0      YKW       NO         14          7
# 186475  14       NO       48.0       NO      BAL          0          0
#
#            seasonState               QB
# 63986   Regular Season  Maximus III, B.
# 64070   Regular Season  Maximus III, B.
# 68808   Regular Season  Maximus III, B.
# 74803   Regular Season  Maximus III, B.
# 85127   Regular Season  Maximus III, B.
# 86299   Regular Season  Maximus III, B.
# 113384  Regular Season  Maximus III, B.
# 114902  Regular Season  Maximus III, B.
# 119153  Regular Season  Maximus III, B.
# 127877  Regular Season  Maximus III, B.
# 137768  Regular Season  Maximus III, B.
# 137785  Regular Season  Maximus III, B.
# 153996  Regular Season  Maximus III, B.
# 161089  Regular Season  Maximus III, B.
# 169319  Regular Season  Maximus III, B.
# 172417  Regular Season  Maximus III, B.
# 176494  Regular Season  Maximus III, B.
# 176630  Regular Season  Maximus III, B.
# 186475  Regular Season  Maximus III, B.

# %% [markdown]
# ***

# %% [markdown]
# ## Wolfie and Micycle

# %%
picksix[picksix.play.str.contains("McDummy, W.")]
# Out:
#         index  Unnamed: 0  teamID  Q   time  totTime  down  distance side  \
# 212313   9704          51       3  1   0:49     2749   2.0      10.0  COL
# 216408  13799         150       3  3   4:11     1151   1.0      10.0  COL
# 216412  13803         154       3  3   3:45     1125   1.0      10.0  COL
# 218886   1153         163       3  3   1:21      981   3.0      10.0  COL
# 233194    577         144       3  3   2:26     1046   3.0      10.0  COL
# 245532  12915          59       3  2  10:51     2451   1.0      10.0  COL
# 262260  14494           3       3  1  14:05     3545   1.0      10.0  COL
# 265362   2464          76       3  2   6:25     2185   3.0       2.0  COL
# 267084   4186          53       3  2  13:48     2628   3.0       7.0  COL
# 279762   1688         169       3  4   8:47      527   1.0      10.0  COL
# 295970    312          83       3  2   8:54     2334   2.0      10.0  COL
# 298760   3102         129       3  3   3:48     1128   2.0       8.0  COL
# 309768  14110         208       3  4   1:04       64   1.0      10.0  COL
# 338200  21239          57       3  2  13:22     2602   2.0       9.0  SJS
#
#         yard                                               play  gameID   S  \
# 212313  43.0  Pass by McDummy, W., to Bishop, J.. INTERCEPTI...    4334  17
# 216408  45.0  Pass by McDummy, W., to Forty-Two (R), L.. INT...    4353  17
# 216412  35.0  Pass by McDummy, W., to Crindy, B.. INTERCEPTI...    4353  17
# 218886  20.0  Pass by McDummy, W., to Damian-Luna, B.. INTER...    4562  18
# 233194  17.0  Pass by McDummy, W., to Owens, A.. INTERCEPTIO...    4808  19
# 245532  20.0  Pass by McDummy, W., to McMahon (R), J.. INTER...    4867  19
# 262260  43.0  Pass by McDummy, W., to Owens, A.. INTERCEPTIO...    5039  20
# 265362  26.0  Pass by McDummy, W., to Owens, A.. INTERCEPTIO...    5165  21
# 267084  23.0  Pass by McDummy, W., to Forty-Two, L.. INTERCE...    5173  21
# 279762  21.0  Pass by McDummy, W., to Vincent, M.. INTERCEPT...    5366  22
# 295970  38.0  Pass by McDummy, W., to Arrow, R.. INTERCEPTIO...    5597  23
# 298760  44.0  Pass by McDummy, W., to Kingston (R), J.. INTE...    5610  23
# 309768  20.0  Pass by McDummy, W., to Kingston (R), J.. INTE...    5663  23
# 338200  47.0  Pass by McDummy, W., to Sauce, E.. INTERCEPTIO...    6192  24
#
#          W teamPoss  dist2goal awayTeam homeTeam  awayScore  homeScore  \
# 212313  10      COL       57.0      OCO      COL          7          0
# 216408  14      COL       55.0      COL      YKW         17         34
# 216412  14      COL       65.0      COL      YKW         17         40
# 218886   2      COL       80.0      COL      BAL          6         38
# 233194   1      COL       83.0      AUS      COL         10         16
# 245532  13      COL       80.0      OCO      COL          7         20
# 262260  14      COL       57.0      COL      YKW          0          0
# 265362   3      COL       74.0      CHI      COL          6          0
# 267084   4      COL       77.0      COL       NO          3          7
# 279762   2      COL       79.0      COL      PHI         17          7
# 295970   1      COL       62.0      PHI      COL          7         10
# 298760   3      COL       56.0      COL      SAR         17         23
# 309768  12      COL       80.0      COL      PHI         13         23
# 338200  19      COL       47.0      SJS      COL          3          3
#
#            seasonState           QB
# 212313  Regular Season  McDummy, W.
# 216408      Postseason  McDummy, W.
# 216412      Postseason  McDummy, W.
# 218886  Regular Season  McDummy, W.
# 233194  Regular Season  McDummy, W.
# 245532  Regular Season  McDummy, W.
# 262260      Postseason  McDummy, W.
# 265362  Regular Season  McDummy, W.
# 267084  Regular Season  McDummy, W.
# 279762  Regular Season  McDummy, W.
# 295970  Regular Season  McDummy, W.
# 298760  Regular Season  McDummy, W.
# 309768  Regular Season  McDummy, W.
# 338200      Postseason  McDummy, W.

# %%
picksix[picksix.play.str.contains("McCormick, M.")]
# Out:
#         index  Unnamed: 0  teamID  Q   time  totTime  down  distance side  \
# 127865   3461         171       3  4  13:13      793   1.0      10.0  COL
# 129043   4639         240       3  4   2:38      158   2.0      10.0  YKW
# 134678  10274          86       3  2   4:28     2068   3.0      10.0  COL
# 138376   1102          10       3  1  13:50     3530   1.0      23.0  COL
# 138420   1146          54       3  1   0:59     2759   1.0      10.0  COL
# 139235   1961         189       3  4  12:24      744   1.0      10.0   AZ
# 143494   6220         189       3  4   4:52      292   4.0       4.0  OCO
# 155860   5950         126       3  3   8:58     1438   1.0      10.0  COL
# 170409   7997         185       3  4   7:13      433   2.0       5.0  COL
# 172693  10281         190       3  4   7:53      473   3.0      11.0  COL
# 173560  11148         207       3  4   3:19      199   1.0      10.0  COL
# 174863     31          31       3  1   5:01     3001   1.0      10.0  COL
# 181982   7150         128       3  3   6:42     1302   1.0      10.0  COL
#
#         yard                                               play  gameID   S  \
# 127865  26.0  Pass by McCormick, M., to (R) Cansino, D.. INT...    2686  11
# 129043  37.0  Pass by McCormick, M., to Chipmunk, A.. INTERC...    2691  11
# 134678   9.0  Pass by McCormick, M., to North, F.. INTERCEPT...    2718  11
# 138376  13.0  Pass by McCormick, M., to Nyquist, W.. INTERCE...    2883  12
# 138420  19.0  Pass by McCormick, M., to Grau, M.. INTERCEPTI...    2883  12
# 139235  46.0  Pass by McCormick, M., to Grau, M.. INTERCEPTI...    2886  12
# 143494  48.0  Pass by McCormick, M., to Chipmunk, A.. INTERC...    2906  12
# 155860  20.0  Pass by McCormick, M., to Miller, H.. INTERCEP...    3040  13
# 170409  34.0  Pass by McCormick, M., to Bishop, J.. INTERCEP...    3242  14
# 172693  12.0  Pass by McCormick, M., to Crindy, B.. INTERCEP...    3253  14
# 173560  22.0  Pass by McCormick, M., to Crindy, B.. INTERCEP...    3257  14
# 174863  43.0  Pass by McCormick, M., to North, F.. INTERCEPT...    3357  15
# 181982  26.0  Pass by McCormick, M., to LaMelllana, S.. INTE...    3390  15
#
#          W teamPoss  dist2goal awayTeam homeTeam  awayScore  homeScore  \
# 127865   4      COL       74.0      COL       NO         20         30
# 129043   6      COL       37.0      YKW      COL         34         51
# 134678  12      COL       91.0      COL      PHI          0         10
# 138376   2      COL       87.0      BAL      COL          0          0
# 138420   2      COL       81.0      BAL      COL         20          0
# 139235   3      COL       46.0       AZ      COL         34         28
# 143494   8      COL       48.0      OCO      COL         38         13
# 155860   8      COL       80.0      COL      PHI         17         16
# 170409  10      COL       66.0       AZ      COL         21         23
# 172693  13      COL       88.0      YKW      COL         20         17
# 173560  14      COL       78.0      OCO      COL         48         23
# 174863   1      COL       57.0      COL      BAL          0          7
# 181982   9      COL       74.0      BAL      COL         21         17
#
#            seasonState             QB
# 127865  Regular Season  McCormick, M.
# 129043  Regular Season  McCormick, M.
# 134678  Regular Season  McCormick, M.
# 138376  Regular Season  McCormick, M.
# 138420  Regular Season  McCormick, M.
# 139235  Regular Season  McCormick, M.
# 143494  Regular Season  McCormick, M.
# 155860  Regular Season  McCormick, M.
# 170409  Regular Season  McCormick, M.
# 172693  Regular Season  McCormick, M.
# 173560  Regular Season  McCormick, M.
# 174863  Regular Season  McCormick, M.
# 181982  Regular Season  McCormick, M.

# %% [markdown]
# ***

# %% [markdown]
# ## Distance to goal

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,7),facecolor='w')
plt.rcParams['font.family'] = 'Roboto Mono'
plt.rcParams['font.weight'] = 'medium'
plt.xlim(0,100)

plt.text(0,73,'Pick Sixes are (obviously) more frequent closer to your own redzone',weight='bold',size=18)
plt.text(0,70,'Number of pick sixes versus distance to goal',weight='light')
plt.xlabel('Distance to goal')
plt.ylabel('Number')

plt.hist(picksix['dist2goal'],bins=np.arange(0,110,5))

plt.tight_layout()
plt.savefig('picksix/dist.png',facecolor=fig.get_facecolor())
plt.show()

# %%
picksix.groupby("QB").min()[['dist2goal']].sort_values('dist2goal').head(10)
# Out:
#                  dist2goal
# QB
# Applehort, R.          6.0
# Phoenix, B.            6.0
# Akselsen, M.           8.0
# Showbiz, G.           12.0
# Jack, C.              13.0
# Bigsby, C.            13.0
# Fitzpatrick, K.       15.0
# Gambino, C.           18.0
# Havran, C.            23.0
# Jenkins, R.           24.0

# %%
picksix.groupby("QB").max()[['dist2goal']].sort_values('dist2goal',ascending=False).head(10)
# Out:
#                  dist2goal
# QB
# Maximus III, B.       99.0
# Cue, J.               99.0
# Bronko, K.            99.0
# Bercovici, J.         98.0
# Jenkins, R.           98.0
# Boss, M.              97.0
# Oles, T.              97.0
# Akselsen, M.          97.0
# Noble, L.             96.0
# Pennington, B.        95.0

# %% [markdown]
# ## Distance to goal

# %%
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(12,7),facecolor='w')
plt.rcParams['font.family'] = 'Roboto Mono'
plt.rcParams['font.weight'] = 'medium'
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])

plt.text(0.5,121,'Pick Sixes are fairly evenly spread out',weight='bold',size=18)
plt.text(0.5,117,'Number of pick sixes in each quarter',weight='light')
plt.xlabel('Q')
plt.ylabel('Number')

plt.hist(picksix['Q'],bins=np.arange(1,7,1),align='left')

plt.tight_layout()
plt.savefig('picksix/q.png',facecolor=fig.get_facecolor())
plt.show()

# %%
picksix.groupby("QB").min()[['totTime']].sort_values('totTime').head(5)
# Out:
#                  totTime
# QB
# Fitzpatrick, K.       24
# Fujiwara, C.          31
# Bercovici, J.         47
# Boss, M.              47
# Pennington, B.        51

# %%
picksix[picksix.play.str.contains("Fujiwara")].sort_values('totTime').head(1)
# Out:
#         index  Unnamed: 0  teamID  Q  time  totTime  down  distance side  \
# 322129   5168         185       1  4  0:31       31   1.0      10.0  BAL
#
#         yard                                               play  gameID   S  \
# 322129  27.0  Pass by Fujiwara, C., to Kaepercolin, N.. INTE...    6156  24
#
#        homeTeam awayTeam teamPoss  dist2goal  awayScore  homeScore  \
# 322129      YKW      BAL      BAL       73.0         21         24
#
#                   QB
# 322129  Fujiwara, C.
