# %% [markdown]
# # PBP Cleaner for ISFL

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
from tqdm.notebook import tqdm
from urllib.request import urlopen
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/mike/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   del sys.path[0]

# %%
pbpDF = pd.read_csv('s22.csv')

# %%
pbpDF.loc[pbpDF['play'].str.contains('FUMBLE')].head(15)
# Out:
#       Unnamed: 0  teamID  Q   time  totTime  down  distance side  yard  \
# 204   22          2       1  8:47   3227     1.0   10.0      YKW  24.0
# 704   71          5       2  4:49   2089     2.0   4.0       HON  41.0
# 809   176         12      4  1:51   111      1.0   10.0      OCO  28.0
# 997   177         8       4  6:28   388      1.0   10.0      SJS  32.0
# 1252  232         4       5  10:54 -246      1.0   10.0      AUS  20.0
# 1633  114         3       3  14:08  1748     1.0   10.0      COL  34.0
# 1655  136         3       3  6:50   1310     2.0   2.0       PHI  23.0
# 2252  113         8       3  12:37  1657     2.0   2.0       OCO  36.0
# 2585  58          1       2  15:00  2700     2.0   9.0       BAL  47.0
# 3104  184         11      4  8:36   516      3.0   6.0       SAR  35.0
# 3126  206         3       4  2:05   125      1.0   10.0      SAR  19.0
# 3470  155         4       4  14:38  878      3.0   2.0       AZ   42.0
# 3482  167         4       4  11:09  669      1.0   10.0      AZ   42.0
# 3780  45          2       1  1:59   2819     1.0   10.0      BAL  13.0
# 3960  17          9       1  11:06  3366     1.0   10.0      CHI  31.0
#
#                                                                                                                                                             play  \
# 204   Rush by Hanyadi, M. for 5 yds. Tackle by Sinclair, Q.. FUMBLE by Hanyadi, M., recovered by Hanyadi, M..
# 704   Rush by Nakamura (R), T. for 1 yds. Tackle by Culbertson, R.. FUMBLE by Nakamura (R), T., recovered by Phillips (R), J..
# 809   Rush by Kane-Maika'i, K. for 5 yds. Tackle by Jones (R), D.. FUMBLE by Kane-Maika'i, K., recovered by Dinkley, V..
# 997   Rush by Gump, F. for 10 yds. Tackle by Staley, T.. FUMBLE by Gump, F., recovered by Gump, F..
# 1252  Rush by Cue, J. for 2 yds. Tackle by Idlewyld, K.. FUMBLE recovered by Idlewyld, K. at the AUS - 18 yard line and returned for 15 yards.
# 1633  Rush by McDummy, W. for 7 yds. Tackle by Howyanow, W.. FUMBLE recovered by Stephens, W. at the COL - 41 yard line and returned for 2 yards.
# 1655  Rush by McDummy, W. for 12 yds. Tackle by Cross (R), M.. FUMBLE recovered by McKinnie, L. at the PHI - 11 yard line and returned for 0 yards.
# 2252  Rush by Francisco, S. for 2 yds. Tackle by Ginsberg, D.. FUMBLE by Francisco, S., recovered by Brew, S..
# 2585  Rush by Reed, A. for 4 yds. Tackle by Howyanow, W.. FUMBLE recovered by Howyanow, W. at the PHI - 49 yard line and returned for 0 yards.
# 3104  Rush by Frost, D. for 0 yds. Tackle by Blackstone, I.. FUMBLE recovered by Thumper, B. at the SAR - 35 yard line and returned for 0 yards.
# 3126  Rush by McDummy, W. for 3 yds. Tackle by Beat, N.. FUMBLE recovered by Beat, N. at the SAR - 16 yard line and returned for 0 yards.
# 3470  Rush by Yoda (R), B. for 6 yds. Tackle by Dissector (R), U.. FUMBLE recovered by Tu'inukuafe, B. at the AZ - 48 yard line and returned for 0 yards.
# 3482  Rush by Cue, J. for 6 yds. Tackle by Dissector (R), U.. FUMBLE recovered by Tu'inukuafe, B. at the AZ - 48 yard line and returned for 0 yards.
# 3780  Rush by Skyline (R), A. for 8 yds. Tackle by De Ville (R), D.. FUMBLE recovered by Stackinpaper (R), B. at the BAL - 5 yard line and returned for 0 yards.
# 3960  Rush by Jenkins, R. for 11 yds. Tackle by Scott (R), R.. FUMBLE recovered by Blackstone, I. at the CHI - 42 yard line and returned for 0 yards.
#
#       gameID   S homeTeam awayTeam teamPoss  dist2goal  awayScore  homeScore
# 204   5360    22  COL      YKW      YKW      76.0       3          0
# 704   5362    22  OCO      HON      OCO      41.0       0          7
# 809   5362    22  OCO      HON      HON      28.0       0          17
# 997   5363    22  NO       SJS      NO       32.0       14         17
# 1252  5364    22  AZ       AUS      AZ       20.0       24         24
# 1633  5366    22  PHI      COL      COL      66.0       17         7
# 1655  5366    22  PHI      COL      COL      23.0       17         7
# 2252  5369    22  NO       OCO      NO       36.0       3          3
# 2585  5371    22  BAL      PHI      BAL      53.0       0          6
# 3104  5373    22  COL      SAR      SAR      65.0       13         22
# 3126  5373    22  COL      SAR      COL      19.0       13         25
# 3470  5375    22  NO       AZ       AZ       42.0       7          16
# 3482  5375    22  NO       AZ       AZ       42.0       7          23
# 3780  5377    22  BAL      YKW      YKW      13.0       13         7
# 3960  5378    22  CHI      COL      CHI      69.0       0          0

# %%
testDF = pbpDF.loc[pbpDF['gameID'] == 5381]

# %%
def playType(x):
    play = x.loc['play']
    if 'Rush' in play:
        return 'Rush'
    elif 'Pass' in play or 'throw' in play or 'SACKED' in play:
        return 'Pass'
    elif 'Penalty' in play:
        return 'Penalty'
    elif 'Punt' in play:
        return 'Punt'
    elif 'kicks off' in play or 'Kickoff' in play:
        return 'Kickoff'
    elif 'FG' in play:
        return 'Field Goal'
    elif 'Timeout' in play:
        return 'Timeout'
    elif 'TOUCHDOWN' in play:
        return 'PAT'
    elif 'Returned by' in play:
        return 'Punt'
    elif 'takes it down' in play or 'waits for blockers' in play or 'endzone' in play or 'return' in play or 'cuts across' in play:
        return 'Kickoff'
    elif 'Turnover' in play:
        return 'Turnover on Downs'
    else:
        return 'N/A'

# %%
tqdm.pandas(desc="Play type")
testDF.loc[:,'playType'] = testDF.progress_apply(lambda x: playType(x),axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Play type', max=202.0, style=ProgressStyle(description_wi…

# %% [markdown]
# ### Passing Columns
#
# Offense:
# `passResult`, `passer`, `receiver`, `incompleteType`
#
# Defense:
# `interceptor`, `passDefender`, `sacker`

# %%
def passResult(x):
    play = x.loc['play']
    playType = x.loc['playType']
    
    if playType == 'Pass':
        if 'incomplete' in play or 'Incomplete' in play or 'throws the ball away' in play:
            return 'Incomplete'
        elif 'complete' in play: return 'Complete'
        elif 'SACKED' in play: return 'Sack'
        elif 'INTERCEPT' in play: return 'Interception'
        else: return 'None'        
    else: return 'N/A'
    
def incompleteType(x):
    play = x.loc['play']
    
    if 'falls incomplete' in play:
        return 'Miss'
    elif 'Broken up' in play:
        return 'Broken up'
    elif 'dropped' in play:
        return 'Dropped'
    elif 'throws the ball away' in play:
        return 'Throw away'
    else:
        return 'N/A'

def passer(x):
    play = x.loc['play']
    passResult = x.loc['passResult']
    incompleteType = x.loc['incompleteType']
    
    if passResult == 'Sack':
        passer = play.split(' SACKED')[0]
    elif passResult == 'Complete':
        passer = play.split('Pass by ')[1].split(', c')[0]
    elif passResult == 'Interception':
        passer = play.split('Pass by ')[1].split(', t')[0]
    elif passResult == 'Incomplete':
        if incompleteType == 'Throw away':
            passer = play.split(' throws')[0]
        else:
            passer = play.split('Pass by ')[1].split(' to')[0]
    else:
        return 'N/A'
    return passer

def receiver(x):
    play = x.loc['play']
    passResult = x.loc['passResult']
    incompleteType = x.loc['incompleteType']
    
    if passResult == 'Incomplete':
        if incompleteType == 'Miss':
            receiver = play.split('to ')[1].split(' falls')[0]
            return receiver
        elif incompleteType == 'Broken up':
            receiver = play.split('to ')[1].split(' is incomplete')[0]
            return receiver
        elif incompleteType == 'Dropped':
            receiver = play.split('to ')[1].split(' was dropped')[0]
            return receiver
        else: return "N/A"
    elif passResult == 'Complete':
        receiver = play.split('complete to ')[1].split(' for')[0]
        return receiver
    elif passResult == 'Interception':
        receiver = play.split('to ')[1].split('. INTERCEPTION')[0]
        return receiver
    else: return "N/A"

# %%
tqdm.pandas(desc="Pass type")
testDF.loc[:,'passResult'] = testDF.progress_apply(lambda x: passResult(x),axis=1)

tqdm.pandas(desc="Incomplete type")
testDF.loc[:,'incompleteType'] = testDF.progress_apply(lambda x: incompleteType(x),axis=1)

tqdm.pandas(desc="Passer")
testDF.loc[:,'passer'] = testDF.progress_apply(lambda x: passer(x),axis=1)

tqdm.pandas(desc="Receiver")
testDF.loc[:,'receiver'] = testDF.progress_apply(lambda x: receiver(x),axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Pass type', max=202.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Incomplete type', max=202.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Passer', max=202.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='Receiver', max=202.0, style=ProgressStyle(description_wid…

# %% [markdown]
# ### Rushing Columns
#
# Offense:
# `rusher`, `rushResult`

# %%
def rushResult(x):
    play = x.loc['play']
    playType = x.loc['playType']
    
    if playType == 'Rush':
        if 'FUMBLE' in play:
            return 'Fumble'
        else:
            return 'Rush'
    else: return 'N/A'
    
def rusher(x):
    play = x.loc['play']
    playType = x.loc['playType']
    
    if playType == 'Rush':
        rusher = play.split('by ')[1].split(' for')[0]
    else:
        return 'N/A'

    return rusher

# %%
tqdm.pandas(desc="Rush type")
testDF.loc[:,'rushResult'] = testDF.progress_apply(lambda x: rushResult(x),axis=1)

tqdm.pandas(desc="rusher")
testDF.loc[:,'rusher'] = testDF.progress_apply(lambda x: rusher(x),axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Rush type', max=202.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='rusher', max=202.0, style=ProgressStyle(description_width…

# %%
# testDF.loc[testDF['playType'] == 'Rush']
testDF.columns
# Out:
# Index(['Unnamed: 0', 'teamID', 'Q', 'time', 'totTime', 'down', 'distance',
#        'side', 'yard', 'play', 'gameID', 'S', 'homeTeam', 'awayTeam',
#        'teamPoss', 'dist2goal', 'awayScore', 'homeScore', 'playType',
#        'passResult', 'incompleteType', 'passer', 'receiver', 'rushResult',
#        'rusher'],
#       dtype='object')

# %% [markdown]
# ### To-Do:
# * ~~Passing~~
# * ~~Receiving~~
# * ~~Rushing~~
# * Defense (tackler, fumbler, fumble recoverer)
# * Field Goals (kickdistance, result, blocker)
# * Punts (kickdistance, result, yards returned, blocker)
# * Extra Points (result, blocker)
# * Play Result (TD/FD/ydGained)
# * Kickoffs (kickdistance, result, yards returned)
# * Dummies using `pd.get_dummies()`

# %%
pd.get_dummies(testDF['passResult'])
# Out:
# 4605  110         4       3  11:15  1575     4.0   8.0       HON  33.0
# 4612  117         4       3  8:48   1428     4.0   15.0      HON  48.0
# 4628  133         4       3  2:36   1056     4.0   13.0      AZ   28.0
# 4629  134         4       3  2:36   1056    NaN   NaN        NaN NaN
# 4657  162         4       4  9:58   598      4.0   10.0      HON  46.0
# 4658  163         4       4  9:58   598     NaN   NaN        NaN NaN
# 4662  167         12      4  9:17   557      4.0   9.0       HON  30.0
# 4663  168         12      4  9:17   557     NaN   NaN        NaN NaN
# 4683  188         12      4  4:32   272      4.0   19.0      AZ   45.0
#
#                                                   play  gameID   S homeTeam  \
# 4504  Punt by Powers, V. of 52 yards. Touchback.        5381    22  AZ
# 4536  Punt by Jay-Jaymison, J. of 55 yards. Touchback.  5381    22  AZ
# 4542  Punt by Powers, V. of 49 yards. No return.        5381    22  AZ
# 4598  Punt by Jay-Jaymison, J. of 47 yards.             5381    22  AZ
# 4599  Returned by Kane-Maika'i (R), K. for 3 yards.     5381    22  AZ
# 4605  Punt by Powers, V. of 33 yards. Touchback.        5381    22  AZ
# 4612  Punt by Powers, V. of 31 yards. No return.        5381    22  AZ
# 4628  Punt by Powers, V. of 51 yards.                   5381    22  AZ
# 4629  Returned by Scarlett, D. for 18 yards.            5381    22  AZ
# 4657  Punt by Powers, V. of 35 yards.                   5381    22  AZ
# 4658  Returned by Scarlett, D. for 18 yards.            5381    22  AZ
# 4662  Punt by Jay-Jaymison, J. of 42 yards.             5381    22  AZ
# 4663  Returned by Kane-Maika'i (R), K. for 4 yards.     5381    22  AZ
# 4683  Punt by Jay-Jaymison, J. of 45 yards. Touchback.  5381    22  AZ
#
#      awayTeam teamPoss  dist2goal  awayScore  homeScore playType passResult  \
# 4504  HON      AZ       47.0       0          0          Punt     N/A
# 4536  HON      HON      55.0       7          7          Punt     N/A
# 4542  HON      AZ       33.0       7          7          Punt     N/A
# 4598  HON      HON      82.0       14         13         Punt     N/A
# 4599  HON      HON     NaN         14         13         Punt     N/A
# 4605  HON      AZ       33.0       14         13         Punt     N/A
# 4612  HON      AZ       48.0       14         13         Punt     N/A
# 4628  HON      AZ       28.0       14         16         Punt     N/A
# 4629  HON      AZ      NaN         14         16         Punt     N/A
# 4657  HON      AZ       46.0       14         23         Punt     N/A
# 4658  HON      AZ      NaN         14         23         Punt     N/A
# 4662  HON      HON      70.0       14         23         Punt     N/A
# 4663  HON      HON     NaN         14         23         Punt     N/A
# 4683  HON      HON      45.0       17         23         Punt     N/A
#
#      incompleteType passer receiver rushResult rusher
# 4504  N/A            N/A    N/A      N/A        N/A
# 4536  N/A            N/A    N/A      N/A        N/A
# 4542  N/A            N/A    N/A      N/A        N/A
# 4598  N/A            N/A    N/A      N/A        N/A
# 4599  N/A            N/A    N/A      N/A        N/A
# 4605  N/A            N/A    N/A      N/A        N/A
# 4612  N/A            N/A    N/A      N/A        N/A
# 4628  N/A            N/A    N/A      N/A        N/A
# 4629  N/A            N/A    N/A      N/A        N/A
# 4657  N/A            N/A    N/A      N/A        N/A
# 4658  N/A            N/A    N/A      N/A        N/A
# 4662  N/A            N/A    N/A      N/A        N/A
# 4663  N/A            N/A    N/A      N/A        N/A
# 4683  N/A            N/A    N/A      N/A        N/A
